# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('Student Depression Dataset.csv')

# %%
dataset
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
dataset.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.isnull().sum().sum()
# Out:
# 3

# %%
dataset.isnull().sum()/len(dataset)*100
# Out:
# id                                       0.000000
# Gender                                   0.000000
# Age                                      0.000000
# City                                     0.000000
# Profession                               0.000000
# Academic Pressure                        0.000000
# Work Pressure                            0.000000
# CGPA                                     0.000000
# Study Satisfaction                       0.000000
# Job Satisfaction                         0.000000
# Sleep Duration                           0.000000
# Dietary Habits                           0.000000
# Degree                                   0.000000
# Have you ever had suicidal thoughts ?    0.000000
# Work/Study Hours                         0.000000
# Financial Stress                         0.010752
# Family History of Mental Illness         0.000000
# Depression                               0.000000
# dtype: float64

# %%
dataset.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     27901 non-null  int64
#  1   Gender                                 27901 non-null  object
#  2   Age                                    27901 non-null  float64
#  3   City                                   27901 non-null  object
#  4   Profession                             27901 non-null  object
#  5   Academic Pressure                      27901 non-null  float64
#  6   Work Pressure                          27901 non-null  float64
#  7   CGPA                                   27901 non-null  float64
#  8   Study Satisfaction                     27901 non-null  float64
#  9   Job Satisfaction                       27901 non-null  float64
# ...

# %%
sns.boxplot(y = 'Financial Stress', data = dataset)
# Out:
# <Axes: ylabel='Financial Stress'>

# %%
dataset['Financial Stress'] = dataset['Financial Stress'].fillna(dataset['Financial Stress'].mean())

# %%
dataset.isna().sum().sum()
# Out:
# 0

# %%
table = pd.crosstab(dataset['Profession'],dataset['Depression'])
table
# Out:
# Depression                  0      1
# Profession
# Architect                   1      7
# Chef                        0      2
# Civil Engineer              0      1
# Content Writer              0      2
# Digital Marketer            1      2
# Doctor                      0      2
# Educational Consultant      0      1
# Entrepreneur                0      1
# Lawyer                      0      1
# Manager                     0      1
# Pharmacist                  0      2
# Student                 11562  16308
# Teacher                     1      5
# UX/UI Designer              0      1

# %%
from scipy.stats import chi2_contingency

# %%
chi2, p, dof, ex = chi2_contingency(table)
print(f"Chi-square Test Result (p-value): chi2 = {chi2}, p-value = {p}")
# Out:
# Chi-square Test Result (p-value): chi2 = 14.288286308637467, p-value = 0.35385931991393843

# %%
table = pd.crosstab(dataset['Gender'],dataset['Depression'])
table
chi2, p, dof, ex = chi2_contingency(table)
print(f"Chi-square Test Result (p-value): chi2 = {chi2}, p-value = {p}")

#Since the p-value is much greater than 0.05, we fail to reject the null hypothesis.
#This means there is no statistically significant association between Gender and Depression in the dataset.
# Out:
# Chi-square Test Result (p-value): chi2 = 0.08265786737059357, p-value = 0.7737273485068406

# %%
table = pd.crosstab(dataset['City'],dataset['Depression'])
table
chi2, p, dof, ex = chi2_contingency(table)
print(f"Chi-square Test Result (p-value): chi2 = {chi2}, p-value = {p}")


#A high Chi-Square statistic indicates a large difference between observed and expected frequencies.

#The p-value is extremely small, much lower than the typical significance level (α=0.05α=0.05).
#This means there is strong evidence to reject the null hypothesis.
# Out:
# Chi-square Test Result (p-value): chi2 = 187.93562916148818, p-value = 1.4718284584775765e-17

# %%
table = pd.crosstab(dataset['Sleep Duration'],dataset['Depression'])
table
chi2, p, dof, ex = chi2_contingency(table)
print(f"Chi-square Test Result (p-value): chi2 = {chi2}, p-value = {p}")

#p-value is extremely small (1.0653e-58), we reject the null hypothesis. 
#This means there is strong evidence to suggest that Sleep Duration and Depression are not independent and 
#that there is a significant association between them.
# Out:
# Chi-square Test Result (p-value): chi2 = 276.8483796551745, p-value = 1.065310789284643e-58

# %%
table = pd.crosstab(dataset['Dietary Habits'],dataset['Depression'])
table
chi2, p, dof, ex = chi2_contingency(table)
print(f"Chi-square Test Result (p-value): chi2 = {chi2}, p-value = {p}")

#p-value is extremely small (1.9625e-260), we reject the null hypothesis. 
#This means there is strong evidence to suggest that Dietary Habits and Depression are not 
#independent and that there is a significant association between them.
# Out:
# Chi-square Test Result (p-value): chi2 = 1202.6381759497453, p-value = 1.9624854819352487e-260

# %%
table = pd.crosstab(dataset['Degree'],dataset['Depression'])
table
chi2, p, dof, ex = chi2_contingency(table)
print(f"Chi-square Test Result (p-value): chi2 = {chi2}, p-value = {p}")

#p-value is extremely small (5.1255e-95), we reject the null hypothesis. 
#This suggests there is strong evidence to conclude that Degree and Depression are not 
#independent and there is a significant association between them.
# Out:
# Chi-square Test Result (p-value): chi2 = 531.3556880193652, p-value = 5.125450008521483e-95

# %%
table = pd.crosstab(dataset['Family History of Mental Illness'],dataset['Depression'])
table
chi2, p, dof, ex = chi2_contingency(table)
print(f"Chi-square Test Result (p-value): chi2 = {chi2}, p-value = {p}")


#The p-value is extremely small (4.98498e-19), we reject the null hypothesis. 
#This means there is strong evidence to suggest that Family History of Mental Illness and 
#Depression are not independent and that there is a significant association between them.
# Out:
# Chi-square Test Result (p-value): chi2 = 79.4344291328439, p-value = 4.9849805086059e-19

# %%
dataset['CGPA'].skew()
# Out:
# -0.11306325679931707

# %%
from scipy.stats import f_oneway

# %%
dataset.head(15)
# Out:
#      id  Gender   Age           City Profession  Academic Pressure  \
# 0     2    Male  33.0  Visakhapatnam    Student                5.0
# 1     8  Female  24.0      Bangalore    Student                2.0
# 2    26    Male  31.0       Srinagar    Student                3.0
# 3    30  Female  28.0       Varanasi    Student                3.0
# 4    32  Female  25.0         Jaipur    Student                4.0
# 5    33    Male  29.0           Pune    Student                2.0
# 6    52    Male  30.0          Thane    Student                3.0
# 7    56  Female  30.0        Chennai    Student                2.0
# 8    59    Male  28.0         Nagpur    Student                3.0
# 9    62    Male  31.0         Nashik    Student                2.0
# 10   83    Male  24.0         Nagpur    Student                3.0
# 11   91    Male  33.0       Vadodara    Student                3.0
# 12   94    Male  27.0         Kalyan    Student                5.0
# ...

# %%
dataset.groupby('Dietary Habits')['CGPA'].mean()
# Out:
# Dietary Habits
# Healthy      7.649656
# Moderate     7.659949
# Others       7.534167
# Unhealthy    7.657331
# Name: CGPA, dtype: float64

# %%
f_stats, p_val = f_oneway(dataset[dataset['Dietary Habits']=='Healthy']['Work/Study Hours'],
                          dataset[dataset['Dietary Habits']=='Moderate']['Work/Study Hours'],
                          dataset[dataset['Dietary Habits']=='Unhealthy']['Work/Study Hours'],
                          dataset[dataset['Dietary Habits']=='Others']['Work/Study Hours'])
print(f"ANOVA Results: F-stats = {f_stats}, p-value = {p_val}")
# Out:
# ANOVA Results: F-stats = 10.271713494204203, p-value = 9.37189275831625e-07

# %%
# !pip install statsmodels

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %%
dataset.columns
# Out:
# Index(['id', 'Gender', 'Age', 'City', 'Profession', 'Academic Pressure',
#        'Work Pressure', 'CGPA', 'Study Satisfaction', 'Job Satisfaction',
#        'Sleep Duration', 'Dietary Habits', 'Degree',
#        'Have you ever had suicidal thoughts ?', 'Work/Study Hours',
#        'Financial Stress', 'Family History of Mental Illness', 'Depression'],
#       dtype='object')

# %%
y = dataset['Depression'] 
x = dataset[['Work/Study Hours','Study Satisfaction', 'Job Satisfaction','Financial Stress']]

# %%
y.shape
# Out:
# (27901,)

# %%
x.shape
# Out:
# (27901, 4)

# %%
from sklearn.model_selection import train_test_split

# %%
x_scaler_train, x_scaler_test, y_train, y_test = train_test_split(x_scaler,y, test_size = 0.2, random_state = 2529)

# %%
x_scaler_train
# Out:
#        Work/Study Hours  Study Satisfaction  Job Satisfaction  \
# 201           -0.042341            0.775949          -0.01534
# 15535         -1.390931            1.510636          -0.01534
# 16185         -1.390931           -0.693425          -0.01534
# 24256         -1.660650           -0.693425          -0.01534
# 17239          0.227377            0.041262          -0.01534
# ...                 ...                 ...               ...
# 3656           0.227377            0.041262          -0.01534
# 22927          1.036531           -1.428112          -0.01534
# 2876           0.227377           -1.428112          -0.01534
# 7730           0.766813            0.775949          -0.01534
# 13664         -0.312059            0.775949          -0.01534
#
#        Financial Stress
# 201           -0.793092
# 15535         -0.097316
# 16185         -0.097316
# 24256         -0.097316
# 17239          1.294237
# ...                 ...
# 3656          -0.793092
# ...

# %%
y_train.value_counts()/len(dataset)*100
# Out:
# Depression
# 1    46.858536
# 0    33.138597
# Name: count, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(class_weight = 'balanced', random_state = 42)

# %%
model.fit(x_scaler_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42)

# %%
y_pred_train = model.predict(x_scaler_train)
y_pred_test = model.predict(x_scaler_test)

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.7000537538075614

# %%
print(accuracy_score(y_test, y_pred_test))
# Out:
# 0.7000537538075614

# %%
print(classification_report(y_test, y_pred_test))
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.69      0.66      2319
#            1       0.76      0.71      0.73      3262
#
#     accuracy                           0.70      5581
#    macro avg       0.69      0.70      0.70      5581
# weighted avg       0.71      0.70      0.70      5581
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.69      0.66      2319
#            1       0.76      0.71      0.73      3262
#
#     accuracy                           0.70      5581
#    macro avg       0.69      0.70      0.70      5581
# weighted avg       0.71      0.70      0.70      5581

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
#feature scalling 
import pandas as pd
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
x_scaler = scaler.fit_transform(x)

# %%
x_scaler = pd.DataFrame(x_scaler, columns=x.columns)

# %%
x_scaler.describe().T.round(2)
# Out:
#                       count  mean  std   min   25%   50%   75%    max
# Work/Study Hours    27901.0   0.0  1.0 -1.93 -0.85  0.23  0.77   1.31
# Study Satisfaction  27901.0   0.0  1.0 -2.16 -0.69  0.04  0.78   1.51
# Job Satisfaction    27901.0   0.0  1.0 -0.02 -0.02 -0.02 -0.02  90.09
# Financial Stress    27901.0  -0.0  1.0 -1.49 -0.79 -0.10  0.60   1.29

# %%
variable = x_scaler
vif = pd.DataFrame()

# %%
vif['Feature'] = x.columns
vif['VIF'] = [variance_inflation_factor(x.values, i) for i in range(x.shape[1])]
print(vif)
# Out:
#               Feature       VIF
# 0    Work/Study Hours  3.641938
# 1  Study Satisfaction  3.504410
# 2    Job Satisfaction  1.000475
# 3    Financial Stress  3.904724

# %%
correlation_matrix = x_scaler.corr()

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
x_reduced = x_scaler.drop(columns=['CGPA'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(7.2,3.5))
plt.hist(dataset['Work/Study Hours'], bins=20, color='blue', alpha=0.7)
plt.title('Histogram of CGPA')
plt.xlabel('Work/Study Hours')
plt.ylabel('CGPA')
plt.show()
